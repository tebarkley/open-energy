# %% [markdown]
# # Energy Team

# %% [markdown]
# To obtain the EIA bulk files
#
# * EIA data bulk files from http://www.eia.gov/beta/api/bulkfiles.cfm
# Basically, at the EIA website you download any of the four high level files. I'm working with the Electricity dataset, at http://api.eia.gov/bulk/ELEC.zip

# %% [markdown]
# ### Installing all the necessary and possibly useful tools:

# %%
try:
    import mpld3
    from mpld3 import enable_notebook
    from mpld3 import plugins
    enable_notebook()
except Exception as e:
    print "Attempt to import and enable mpld3 failed", e

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import codecs
import os

#import patsy
import csv
import xlwt

from us import states
from pandas import *
from itertools import islice
from pandas import ExcelWriter
from pandas.stats.api import ols
from pylab import figure, show, savefig
from pandas import DataFrame, Series
from matplotlib.lines import *
from matplotlib.colors import NoNorm

# %% [markdown]
# ### Getting and activating an API key:

# %%
#If you don't have an EIA API key, request one. Create a file in the same directory as this notebook called
#EIA_Settings.py, and create a string called EIA_KEY that stores the key
# This cell should run successfully if you have a string set up to represent your census key

try:
    import EIA_settings
    assert type(EIA_settings.EIA_KEY) == str or type(EIA_settings.EIA_KEY) == unicode
except Exception as e:
    print "error in importing settings to get at settings.EIA_KEY", e

# %% [markdown]
# ### One way of getting category ids, but I didn't use it:

# %%
import EIA_settings
import requests
import json

EIA_url = "".join(list("http://api.eia.gov/category?api_key="+ EIA_settings.EIA_KEY+ "&category_id=*"))
print EIA_url

r = requests.get(EIA_url).json()
# Out:
# http://api.eia.gov/category?api_key=2f7e02f0cf9c4f65f8a736C468561B8C9C6D92C513A5018CA8D47db672eb2e6482fd87fe&category_id=*

# %% [markdown]
# ### More info from the EIA website that up to now hasn't been much useful:

# %%
manifest = "http://api.eia.gov/bulk/manifest.txt"
mani_text = requests.get(manifest).json()
#mani_text["dataset"]["COAL"]#['accessURL']
print mani_text
# Out:
# {u'dataset': {u'PET': {u'accessURL': u'http://api.eia.gov/bulk/PET.zip', u'publisher': u'U.S. Energy Information Administration', u'identifier': u'PET', u'last_updated': u'2014-04-15T07:19:20-04:00', u'name': u'Petroleum', u'keyword': u'United States petroleum liquid fuel production imports refining exports prices consumption stocks reserves', u'title': u'Petroleum and other liquid fuels', u'data_set': u'PET', u'accessLevel': u'public', u'format': u'XML and JSON data API, JSON download file', u'modified': u'2014-04-15T07:19:20-04:00', u'accessLevelComment': u'series copyright field contains further information ', u'person': u'Mark Elbert', u'webService': u'http://api.eia.gov', u'spatial': u'United States of America, PADD, state-level, trade country', u'license': None, u'category_id': u'714755', u'mbox': u'data@eia.gov', u'temporal': u'daily, weekly, monthly, quarterly, annual', u'description': u'Statistics of U.S. petroleum and other liquid fuel production, imports, refining, exports, prices, consumption, stocks, and reserves'}, u'COAL': {u'accessURL': u'http://api.eia.gov/bulk/COAL.zip', u'publisher': u'U.S. Energy Information Administration', u'identifier': u'COAL', u'last_updated': u'2014-04-09T07:12:15-04:00', u'name': u'Coal', u'keyword': u'United States state coal mine production quality consumption shipments import export capacity reserves electric power', u'title': u'Coal', u'data_set': u'COAL', u'accessLevel': u'public', u'format': u'XML and JSON data API, JSON download file', u'modified': u'2014-04-09T07:12:15-04:00', u'accessLevelComment': u'series copyright field contains further information ', u'person': u'Mark Elbert', u'webService': u'http://api.eia.gov', u'spatial': u'United States of America, state-level, mine-level', u'license': None, u'category_id': u'717234', u'mbox': u'data@eia.gov', u'temporal': u'quarterly, annual', u'description': u'Aggregate national, state, and mine-level coal production statistics, including imports and exports, reciepts of coal at electric power plants, consumption and quality, market sales, reserves, and productive capacity'}, u'NG': {u'accessURL': u'http://api.eia.gov/bulk/NG.zip', u'publisher': u'U.S. Energy Information Administration', u'identifier': u'NG', u'last_updated': u'2014-04-11T07:18:06-04:00', u'name': u'Natural Gas', u'keyword': u'United States natural gas production imports exploration pipelines exports prices consumption stocks reserves', u'title': u'Natural Gas', u'data_set': u'NG', u'accessLevel': u'public', u'format': u'XML and JSON data API, JSON download file', u'modified': u'2014-04-11T07:18:06-04:00', u'accessLevelComment': u'series copyright field contains further information ', u'person': u'Mark Elbert', u'webService': u'http://api.eia.gov', u'spatial': u'United States of America, state-level, trade country', u'license': None, u'category_id': u'714804', u'mbox': u'data@eia.gov', u'temporal': u'daily, weekly, monthly, quarterly, annual', u'description': u'Statistics of U.S. natural gas production, imports, exploration, pipelines, exports, prices, consumption, stocks, and reserves'}, u'ELEC': {u'accessURL': u'http://api.eia.gov/bulk/ELEC.zip', u'publisher': u'U.S. Energy Information Administration', u'identifier': u'ELEC', u'last_updated': u'2014-03-24T11:26:17-04:00', u'name': u'Electricity', u'keyword': u'United States state electricity plant generation fuel quality consumption grid-connected plants', u'title': u'Electricity', u'data_set': u'ELEC', u'accessLevel': u'public', u'format': u'XML and JSON data API, JSON download file', u'modified': u'2014-03-24T11:26:17-04:00', u'accessLevelComment': u'series copyright field contains further information ', u'person': u'Mark Elbert', u'webService': u'http://api.eia.gov', u'spatial': u'United States of America, state-level, plant-level', u'license': None, u'category_id': u'0', u'mbox': u'data@eia.gov', u'temporal': u'monthly, quarterly, annual', u'description': u'Aggregate national, state, and plant-level electric ...

# %% [markdown]
# ### Getting the bulk electricity data and pulling it into a data structure

# %%
#txt_dir = "C:/Users/Pablito/Documents/Berkeley/opendata/Final project/EIA bulk files/"
txt_dir = "/Users/Peter_Swigert/Documents/Berkeley/I_School/Open_Data/Final_Project/Data/"
#/Users/Peter_Swigert/Documents/Berkeley/I_School/Open_Data/Final_Project/Data
f_location = (txt_dir+"ELEC.txt")
f = open(f_location, 'r')
raw_data = []
temp_data = []



from itertools import islice
with open(f_location, 'r') as f:
    #Edit it to pull in everything. Get rid of the islice entirely maybe?
    for row in f: #was doing it on 100,000
        line = json.loads(row)
        #Edit this to make it the actual rows that I want (annual, by sector etc)
        if 'Retail Sales of Electricity' in line['name']:
            if 'Annual' in line['name']:
                raw_data.append(line)
        

#part_of_data = raw_data[0:1000]
print len(raw_data)
# Out:
# 700

# %%
print raw_data[:5]
# Out:
# [{u'end': u'2013', u'description': u'Electricity sold to transportation customers; Electricity sold to transportation customers; ', u'copyright': u'None', u'f': u'A', u'data': [[u'2013', 61.57434], [u'2012', 70.18104], [u'2011', 68.32902], [u'2010', 74.444], [u'2009', 70.90699], [u'2008', 68.54401], [u'2007', 67.019], [u'2006', 61.75399], [u'2005', 70.606], [u'2004', 81.346], [u'2003', 89.99999], [u'2002', None], [u'2001', None]], u'series_id': u'ELEC.SALES.T
names = []
my_data = []
my_dict = {}

for x in raw_data:
    if 'Retail Sales of Electricity' in x['name'] and 'Annual' in x['name']: #Retail Sales of Electricity : Alaska : Residential/Commercial/Industrial/Transportation/Other : Annual
        my_dict[x['name']]=x['data']

# %% [markdown]
# ### Okay let's actually start working with the dataframe

# %% [markdown]
# ### Getting restarted here using a dataframe called d2. Previous approach with my_df didn't work out too well.

# %%
df = pd.DataFrame(my_dict)
df.head()
# Out:
#   Retail Sales of Electricity : Alabama : All Sectors : Annual  \
# 0                                [2013, 88146.89146]
# 1                                [2012, 86182.54801]
# 2                                [2011, 88995.36901]
# 3                                [2010, 90862.64499]
# 4                                  [2009, 82844.602]
#
#   Retail Sales of Electricity : Alabama : Commercial : Annual  \
# 0                                [2013, 22464.84297]
# 1                                  [2012, 21799.181]
# 2                                [2011, 22257.12701]
# 3                                [2010, 22983.76799]
# 4                                [2009, 21918.47799]
#
#   Retail Sales of Electricity : Alabama : Industrial : Annual  \
# 0                                [2013, 34247.79568]
# 1                                [2012, 33751.10602]
# 2                                  [2011, 33735.427]
# 3                                [2010, 32349.58502]
# 4                                [2009, 29436.71299]
#
#   Retail Sales of Electricity : Alabama : Other : Annual  \
# 0                                       [2013, None]
# 1                                       [2012, None]
# 2                                       [2011, None]
# 3                                       [2010, None]
# 4                                       [2009, None]
#
#   Retail Sales of Electricity : Alabama : Residential : Annual  \
# 0                                [2013, 31434.25283]
# 1                                [2012, 30632.26102]
# 2                                [2011, 33002.81499]
# 3                                  [2010, 35529.292]
# 4                                [2009, 31489.41101]
#
#   Retail Sales of Electricity : Alaska : All Sectors : Annual  \
# 0                                 [2013, 6261.28625]
# 1                                 [2012, 6416.41098]
# 2                                    [2011, 6319.54]
# 3                                 [2010, 6247.03802]
# 4                                 [2009, 6269.92701]
#
#   Retail Sales of Electricity : Alaska : Commercial : Annual  \
# 0                                 [2013, 2822.16579]
# 1                                   [2012, 2875.038]
# 2                                 [2011, 2854.40999]
# 3                                 [2010, 2829.73801]
# 4                                 [2009, 2841.21199]
#
#   Retail Sales of Electricity : Alaska : Industrial : Annual  \
# 0                                 [2013, 1333.60932]
# 1                                 [2012, 1381.17701]
# 2                                 [2011, 1330.70803]
# 3                                   [2010, 1324.083]
# 4                                 [2009, 1311.44099]
#
#   Retail Sales of Electricity : Alaska : Other : Annual  \
# 0                                       [2013, None]
# 1                                       [2012, None]
# 2                                       [2011, None]
# 3                                       [2010, None]
# 4                                       [2009, None]
#
#   Retail Sales of Electricity : Alaska : Residential : Annual  \
# 0                                 [2013, 2105.51114]
# 1                                 [2012, 2160.19598]
# 2                                 [2011, 2134.42201]
# 3                                   [2010, 2093.217]
# 4                                   [2009, 2117.274]
#
#   Retail Sales of Electricity : Arizona : All Sectors : Annual  \
# 0                                [2013, 75690.61254]
# 1                                [2012, 75063.34301]
# 2                                  [2011, 74943.645]
# 3                                [2010, 72833.03001]
# 4                                [2009, 73432.92901]
#
#   Retail Sales of Electricity : Arizona : Commercial : Annual  \
# 0                                [2013, 29951.76842]
# 1                                  [2012, 29692.256]
# 2                                [2011, 29512.33001]
# 3                                [2010, 28942.91802]
# 4                                [2009, 29385.69001]
#
#   Retail Sales of Electricity : Arizona : Industrial : Annual  \
# 0                                [2013, 12600.36554]
# 1                                [2012, 12448.11701]
# 2                                [2011, 12352.24101]
# 3                                [2010, 11441.97399]
# 4                                [2009, 11200.39602]
#
#   Retail Sales of Electricity : Arizona : Other : Annual  \
# 0                                       [2013, None]
# 1                                       [2012, None]
# 2                                       [2011, None]
# 3                                       [2010, None]
# 4                                       [2009, None]
#
#   Retail Sales of Electricity : Arizona : Residential : Annual  \
# 0                                 [2013, 33138.4786]
# 1                                [2012, 32922.97001]
# 2                                [2011, 33079.07402]
# 3                                [2010, 32448.13802]
# 4                                [2009, 32846.84298]
#
#   Retail Sales of Electricity : Arkansas : All Sectors : Annual  \
# 0                                [2013, 46677.83412]
# 1                                  [2012, 46859.567]
# 2                                  [2011, 47927.829]
# 3                                [2010, 48194.28502]
# 4                                  [2009, 43173.104]
#
#   Retail Sales of Electricity : Arkansas : Commercial : Annual  \
# 0                                [2013, 11891.11628]
# 1                                [2012, 12102.04799]
# 2                                [2011, 12146.12999]
# 3                                [2010, 12188.20499]
# 4                                [2009, 11476.90001]
#
#   Retail Sales of Electricity : Arkansas : Industrial : Annual  \
# 0                                [2013, 16709.19272]
# 1                                [2012, 16847.75502]
# 2                                [2011, 16993.92202]
# 3                                [2010, 16774.69902]
# 4                                  [2009, 14710.294]
#
#   Retail Sales of Electricity : Arkansas : Other : Annual  \
# 0                                       [2013, None]
# 1                                       [2012, None]
# 2                                       [2011, None]
# 3                                       [2010, None]
# 4                                       [2009, None]
#
#   Retail Sales of Electricity : Arkansas : Residential : Annual
# 0                                [2013, 18077.16915]            ...
# 1                                [2012, 17909.30101]            ...
# 2                                [2011, 18787.34901]            ...
# 3                                  [2010, 19230.961]            ...
# 4                                [2009, 16985.52599]            ...
#
# [5 rows x 700 columns]

# %%
#Let's pull the column header into each record
d2 = df.unstack().reset_index()

#And rename the column header to swe get the data
d2 = d2.rename(columns={0: "Sales"})
d2.head(20)
# Out:
#                                               level_0  level_1  \
# 0   Retail Sales of Electricity : Alabama : All Se...        0
# 1   Retail Sales of Electricity : Alabama : All Se...        1
# 2   Retail Sales of Electricity : Alabama : All Se...        2
# 3   Retail Sales of Electricity : Alabama : All Se...        3
# 4   Retail Sales of Electricity : Alabama : All Se...        4
# 5   Retail Sales of Electricity : Alabama : All Se...        5
# 6   Retail Sales of Electricity : Alabama : All Se...        6
# 7   Retail Sales of Electricity : Alabama : All Se...        7
# 8   Retail Sales of Electricity : Alabama : All Se...        8
# 9   Retail Sales of Electricity : Alabama : All Se...        9
# 10  Retail Sales of Electricity : Alabama : All Se...       10
# 11  Retail Sales of Electricity : Alabama : All Se...       11
# 12  Retail Sales of Electricity : Alabama : All Se...       12
# 13  Retail Sales of Electricity : Alabama : Commer...        0
# 14  Retail Sales of Electricity : Alabama : Commer...        1
# 15  Retail Sales of Electricity : Alabama : Commer...        2
# 16  Retail Sales of Electricity : Alabama : Commer...        3
# 17  Retail Sales of Electricity : Alabama : Commer...        4
# 18  Retail Sales of Electricity : Alabama : Commer...        5
# 19  Retail Sales of Electricity : Alabama : Commer...        6
#
#                   Sales
# 0   [2013, 88146.89146]
# 1   [2012, 86182.54801]
# 2   [2011, 88995.36901]
# 3   [2010, 90862.64499]
# 4     [2009, 82844.602]
# 5   [2008, 89707.27901]
# 6   [2007, 91828.46399]
# 7   [2006, 90677.69499]
# 8   [2005, 89201.61999]
# 9     [2004, 86870.519]
# 10  [2003, 83844.22002]
# 11  [2002, 83067.07798]
# 12  [2001, 79358.25799]
# 13  [2013, 22464.84297]
# 14    [2012, 21799.181]
# 15  [2011, 22257.12701]
# 16  [2010, 22983.76799]
# 17  [2009, 21918.47799]
# 18  [2008, 22533.11999]
# 19  [2007, 22872.54301]
#
# [20 rows x 3 columns]

# %%
#Then split the column header field into its components
parts = d2.pop("level_0").str.split(":")
parts.to_csv("parts")

# %%
#And now create new columns based on those components
d2["State"] = [p[1].strip() for p in parts]
d2["Sector"] = [p[2].strip() for p in parts]

# %%
#d2['Year'] = d2[['Sales']]
d2.head(20)

#my_df = my_df.applymap(lambda x: x[-1])
# Out:
#     level_1                Sales    State       Sector
# 0         0  [2013, 88146.89146]  Alabama  All Sectors
# 1         1  [2012, 86182.54801]  Alabama  All Sectors
# 2         2  [2011, 88995.36901]  Alabama  All Sectors
# 3         3  [2010, 90862.64499]  Alabama  All Sectors
# 4         4    [2009, 82844.602]  Alabama  All Sectors
# 5         5  [2008, 89707.27901]  Alabama  All Sectors
# 6         6  [2007, 91828.46399]  Alabama  All Sectors
# 7         7  [2006, 90677.69499]  Alabama  All Sectors
# 8         8  [2005, 89201.61999]  Alabama  All Sectors
# 9         9    [2004, 86870.519]  Alabama  All Sectors
# 10       10  [2003, 83844.22002]  Alabama  All Sectors
# 11       11  [2002, 83067.07798]  Alabama  All Sectors
# 12       12  [2001, 79358.25799]  Alabama  All Sectors
# 13        0  [2013, 22464.84297]  Alabama   Commercial
# 14        1    [2012, 21799.181]  Alabama   Commercial
# 15        2  [2011, 22257.12701]  Alabama   Commercial
# 16        3  [2010, 22983.76799]  Alabama   Commercial
# 17        4  [2009, 21918.47799]  Alabama   Commercial
# 18        5  [2008, 22533.11999]  Alabama   Commercial
# 19        6  [2007, 22872.54301]  Alabama   Commercial
#
# [20 rows x 4 columns]

# %%
#Let's create a dictionary we can use to switch the level_1 fields to the actual years
temp_vals = range(0,13)
temp_years = sorted(range(2001,2014), reverse=True)

year_setter_dict = {}
for i in range(len(temp_vals)):
   year_setter_dict[temp_vals[i]] = temp_years[i]
print year_setter_dict
# Out:
# {0: 2013, 1: 2012, 2: 2011, 3: 2010, 4: 2009, 5: 2008, 6: 2007, 7: 2006, 8: 2005, 9: 2004, 10: 2003, 11: 2002, 12: 2001}

# %%
#Turns the a column into years based on the dictionary matching
d2['level_1'] = d2['level_1'].map(lambda x: year_setter_dict[x])

# %%
#d2.rename(columns={'a': 'Year'}, inplace=True)

# %%
d2.head()
# Out:
#    level_1                Sales    State       Sector
# 0     2013  [2013, 88146.89146]  Alabama  All Sectors
# 1     2012  [2012, 86182.54801]  Alabama  All Sectors
# 2     2011  [2011, 88995.36901]  Alabama  All Sectors
# 3     2010  [2010, 90862.64499]  Alabama  All Sectors
# 4     2009    [2009, 82844.602]  Alabama  All Sectors
#
# [5 rows x 4 columns]

# %%
#Now let's get rid of the year inside of the cell
import operator
d2['Year']=d2.Sales.apply(operator.itemgetter(-1), axis=1)
d2.head()
# Out:
#    level_1                Sales    State       Sector         Year
# 0     2013  [2013, 88146.89146]  Alabama  All Sectors  88146.89146
# 1     2012  [2012, 86182.54801]  Alabama  All Sectors  86182.54801
# 2     2011  [2011, 88995.36901]  Alabama  All Sectors  88995.36901
# 3     2010  [2010, 90862.64499]  Alabama  All Sectors  90862.64499
# 4     2009    [2009, 82844.602]  Alabama  All Sectors  82844.60200
#
# [5 rows x 5 columns]

# %%
d2.rename(columns={'Year':'Data'}, inplace=True)
d2.head()
# Out:
#    level_1                Sales    State       Sector         Data
# 0     2013  [2013, 88146.89146]  Alabama  All Sectors  88146.89146
# 1     2012  [2012, 86182.54801]  Alabama  All Sectors  86182.54801
# 2     2011  [2011, 88995.36901]  Alabama  All Sectors  88995.36901
# 3     2010  [2010, 90862.64499]  Alabama  All Sectors  90862.64499
# 4     2009    [2009, 82844.602]  Alabama  All Sectors  82844.60200
#
# [5 rows x 5 columns]

# %% [markdown]
# ### Below is a final, useful dataframe with the columns for year, state, sector and sales. So each state/year/sector row is unique.

# %%
del d2['Sales']
d2.rename(columns={'Data': 'Sales'}, inplace=True)
d2.rename(columns={'level_1': 'Year'}, inplace=True)
d2.head(20)
# Out:
#     Year    State       Sector        Sales
# 0   2013  Alabama  All Sectors  88146.89146
# 1   2012  Alabama  All Sectors  86182.54801
# 2   2011  Alabama  All Sectors  88995.36901
# 3   2010  Alabama  All Sectors  90862.64499
# 4   2009  Alabama  All Sectors  82844.60200
# 5   2008  Alabama  All Sectors  89707.27901
# 6   2007  Alabama  All Sectors  91828.46399
# 7   2006  Alabama  All Sectors  90677.69499
# 8   2005  Alabama  All Sectors  89201.61999
# 9   2004  Alabama  All Sectors  86870.51900
# 10  2003  Alabama  All Sectors  83844.22002
# 11  2002  Alabama  All Sectors  83067.07798
# 12  2001  Alabama  All Sectors  79358.25799
# 13  2013  Alabama   Commercial  22464.84297
# 14  2012  Alabama   Commercial  21799.18100
# 15  2011  Alabama   Commercial  22257.12701
# 16  2010  Alabama   Commercial  22983.76799
# 17  2009  Alabama   Commercial  21918.47799
# 18  2008  Alabama   Commercial  22533.11999
# 19  2007  Alabama   Commercial  22872.54301
#
# [20 rows x 4 columns]

# %%
d2.to_csv("d2")

# %% [markdown]
# ### Let's start working with just 2013 data for right now, as I want to build a visualization on that

# %%
df_2013 = d2.ix[d2['Year'] == 2013]
df_2013.head(20)
# Out:
#      Year     State       Sector        Sales
# 0    2013   Alabama  All Sectors  88146.89146
# 13   2013   Alabama   Commercial  22464.84297
# 26   2013   Alabama   Industrial  34247.79568
# 39   2013   Alabama        Other          NaN
# 52   2013   Alabama  Residential  31434.25283
# 65   2013    Alaska  All Sectors   6261.28625
# 78   2013    Alaska   Commercial   2822.16579
# 91   2013    Alaska   Industrial   1333.60932
# 104  2013    Alaska        Other          NaN
# 117  2013    Alaska  Residential   2105.51114
# 130  2013   Arizona  All Sectors  75690.61254
# 143  2013   Arizona   Commercial  29951.76842
# 156  2013   Arizona   Industrial  12600.36554
# 169  2013   Arizona        Other          NaN
# 182  2013   Arizona  Residential  33138.47860
# 195  2013  Arkansas  All Sectors  46677.83412
# 208  2013  Arkansas   Commercial  11891.11628
# 221  2013  Arkansas   Industrial  16709.19272
# 234  2013  Arkansas        Other          NaN
# 247  2013  Arkansas  Residential  18077.16915
#
# [20 rows x 4 columns]

# %%
df_2013.to_csv("df_2013")

# %% [markdown]
# ### And we will make a pivot of the 2013 data so we can have it broken down by sector for each state

# %%
#print df_2013.index.name

pivot_2013 = pivot_table(df_2013, values='Sales', rows='State', cols='Sector', aggfunc=np.sum)
#pivot_2013 = df_2013.pivot(index=df_2013.index, columns='Sector', values='Sales')
#Let's get rid of the "Other" data, it is empty, and the "Transportation" data, because it is sparce
del pivot_2013['Other']
del pivot_2013['Transportation']
#And let's sort it by Total so we can see the top
pivot_2013 = pivot_2013.sort(['All Sectors'], ascending=False)
pivot_2013.to_csv("pivot_2013")
print pivot_2013
# Out:
#                                  All Sectors     Commercial     Industrial  \
# State
# United States                  4063996.54721  1476225.92766  1019836.15658
# South Atlantic (Total)          863917.14127   332467.24624   148200.71535
# East North Central (Total)      617756.12589   200873.92536   206022.92019
# West South Central (Total)      606276.54485   206385.00008   165404.84745
# Pacific Contiguous (Total)      445248.02547   187625.97057    93143.85779
# Middle Atlantic (Total)         410675.30401   178080.28703    73950.94375
# Texas                           399793.69839   145936.65071    97878.72600
# East South Central (Total)      343937.07286    99258.30996   115276.92150
# West North Central (Total)      320085.48924   109967.11348    93272.15705
# Mountain (Total)                298336.86288   102715.88949    88195.24775
# California                      294405.57514   138568.89022    51633.83192
# Florida                         244203.20641   100278.15409    18105.41444
# New York                        165793.85118    87900.59638    14521.83030
# Ohio                            162428.46830    51211.72758    52966.97240
# Pennsylvania                    160283.50693    47139.56386    51257.64635
# Illinois                        152866.85881    55044.49748    45938.36060
# Georgia                         144213.91548    50499.26984    33144.53813
# North Carolina                  141560.68715    50905.09421    28497.29233
# New England (Total)             137806.99873    51206.51705    30119.33634
# Virginia                        119952.27659    51607.29123    18096.99138
# Michigan                        114003.43726    42050.87357    32994.78839
# Indiana                         112377.09917    26704.47011    48995.47149
# Tennessee                       104893.84328    36891.78901    23132.81057
# Washington                       99550.33058    31702.05261    28878.63430
# Alabama                          96099.27105    24824.10207    36298.91417
# Louisiana                        92456.90220    26452.23999    32630.20062
# Missouri                         89779.08774    33628.56858    17600.79572
# Kentucky                         89697.12938    22454.43245    38103.51048
# South Carolina                   86113.45580    23268.28026    30379.75002
# New Jersey                       84597.94593    43040.12682     8171.46712
# Arizona                          83380.30700    32907.79365    13443.43235
# Wisconsin                        76080.26241    25862.35663    25127.32742
# Minnesota                        73807.15194    24769.22415    23742.52465
# Maryland                         69132.49941    33371.32483     4251.57069
# Oklahoma                         63697.28967    21156.01610    17203.54961
# Massachusetts                    62395.08094    20110.60443    18169.03666
# Colorado                         59148.76831    21699.23817    16607.86733
# Mississippi                      53246.82914    15087.98641    17741.68628
# Oregon                           51292.11974    17355.02775    12631.39160
# Arkansas                         50328.65463    12840.09332    17692.37127
# Iowa                             50264.18185    13420.95915    20762.34274
# Kansas                           43488.15713    16959.18220    11412.41984
# Nevada                           38303.40697    10144.70124    14571.40453
# Connecticut                      34362.52561    14936.39307     3822.42469
# West Virginia                    33874.06798     8427.99267    12763.84677
# Utah                             32815.51221    11788.49704    10641.37882
# Nebraska                         32631.14609    10186.86940    11378.33862
# Idaho                            25818.32576     6540.92296     9868.39993
# New Mexico                       25324.49481     9876.59171     7843.71704
# Pacific Noncontiguous (Total)    19956.98217     7645.66846     6249.20953
# Wyoming                          18353.40896     4407.28297    10819.30877
# North Dakota                     17010.03594     5940.63368     5578.44394
# Montana                          15192.63895     5350.86185     4399.73902
# Maine                            13246.73415     4578.48836     3341.40135
# South Dakota                     13105.72862     5061.67639     2797.29165
# Hawaii                           12661.52994     4382.57737     4705.30542
# New Hampshire                    12566.81831     5111.49026     2182.98623
# Delaware                         12467.52818     4596.79328     2720.53806
# District of Columbia             12399.50430     9513.04595      240.77363
# Rhode Island                      8869.02399     4145.32222     1036.42720
#                                          ...            ...            ...
#
#                                  Residential
# State
# United States                  1559635.75003
# South Atlantic (Total)          381814.48301
# East North Central (Total)      210177.89096
# West South Central (Total)      234406.07983
# Pacific Contiguous (Total)      163695.46588
# Middle Atlantic (Total)         154137.27226
# Texas                           155910.51711
# East South Central (Total)      129399.85562
# West North Central (Total)      116801.71958
# Mountain (Total)                107288.69007
# California                      103450.50272
# Florida                         125720.17880
# New York                         60116.07754
# Ohio                             58202.80296
# Pennsylvania                     60988.39316
# Illinois                         51279.66483
# Georgia                          60401.05654
# North Carolina                   62150.30751
# New England (Total)              55852.18868
# Virginia                         50037.49273
# Michigan                         38951.00468
# Indiana                          36653.84015
# Tennessee                        44867.25792
# Washington                       38963.73157
# Alabama                          34976.25480
# Louisiana                        33362.04618
# Missouri                         38526.19614
# Kentucky                         29139.18645
# South Carolina                   32465.42548
# New Jersey                       33032.80161
# Arizona                          37029.08100
# Wisconsin                        25090.57839
# Minnesota                        25274.43139
# Maryland                         30922.78361
# Oklahoma                         25337.72400
# Massachusetts                    23725.51573
# Colorado                         20773.49415
# Mississippi                      20417.15649
# Oregon                           21281.23163
# Arkansas                         19795.79251
# Iowa                             16080.88001
# Kansas                           15116.55515
# Nevada                           13578.32419
# Connecticut                      15394.63834
# West Virginia                    12677.90101
# Utah                             10325.74659
# Nebraska                         11065.93807
# Idaho                             9409.00286
# New Mexico                        7604.18609
# Pacific Noncontiguous (Total)     6062.10419
# Wyoming                           3126.81724
# North Dakota                      5490.95828
# Montana                           5442.03809
# Maine                             5326.84447
# South Dakota                      5246.76058
# Hawaii                            3573.64721
# New Hampshire                     5272.34188
# Delaware                          5150.19689
# District of Columbia              2289.14055
# Rhode Island                      3657.31165
#                                          ...
#
# [62 rows x 4 columns]

# %% [markdown]
# #### So it turns out that this data includes a lot of geographies that aren't states. I just want states.

# %%
#Gets all the states from the Census. Really could have gotten that list from anywhere
assert states.CA.fips == u'06'
states_list = []
for (i, state) in enumerate(states.STATES):
    State = str(state).replace("<State:","").replace(">","")
    states_list.append(State)

# %%
temp_pivot = pivot_2013
#It wasn't letting me compare the index to the list of states, so I make a temporary column called states
temp_pivot['State'] = pivot_2013.index

# %%
#pivot_2013 = pivot_2013.ix[pivot_2013['State'] in states_list]
just_states_df = temp_pivot[temp_pivot['State'].isin(states_list)]
del just_states_df['State']
just_states_df.to_csv("just_states_df")
print just_states_df
