# %% [markdown]
# ### Imports

# %%
import census
import settings
import us
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
from itertools import islice
import csv
import json

from us import states

# %% [markdown]
# ### State Populations- for getting per capita information

# %%
#You need to have a file with the API key
c=census.Census(settings.CENSUS_KEY)

# call the API and instantiate `df`
c_pop_df = pd.DataFrame(c.sf1.get('NAME,P0010001', geo={'for':'state:*'}))
# convert the population to integer
c_pop_df['P0010001'] = c_pop_df['P0010001'].astype(np.int)
c_pop_df.rename(columns={'P0010001':'Population','state':'FIPS'}, inplace=True) 
#Get rid of Puerto Rico
c_pop_df = c_pop_df[c_pop_df['NAME'] != 'Puerto Rico']
c_pop_df.head(51)
# Out:
#                     NAME  Population FIPS
# 0                Alabama     4779736   01
# 1                 Alaska      710231   02
# 2                Arizona     6392017   04
# 3               Arkansas     2915918   05
# 4             California    37253956   06
# 5               Colorado     5029196   08
# 6            Connecticut     3574097   09
# 7               Delaware      897934   10
# 8   District of Columbia      601723   11
# 9                Florida    18801310   12
# 10               Georgia     9687653   13
# 11                Hawaii     1360301   15
# 12                 Idaho     1567582   16
# 13              Illinois    12830632   17
# 14               Indiana     6483802   18
# 15                  Iowa     3046355   19
# 16                Kansas     2853118   20
# 17              Kentucky     4339367   21
# 18             Louisiana     4533372   22
# 19                 Maine     1328361   23
# 20              Maryland     5773552   24
# 21         Massachusetts     6547629   25
# 22              Michigan     9883640   26
# 23             Minnesota     5303925   27
# 24           Mississippi     2967297   28
# 25              Missouri     5988927   29
# 26               Montana      989415   30
# 27              Nebraska     1826341   31
# 28                Nevada     2700551   32
# 29         New Hampshire     1316470   33
# 30            New Jersey     8791894   34
# 31            New Mexico     2059179   35
# 32              New York    19378102   36
# 33        North Carolina     9535483   37
# 34          North Dakota      672591   38
# 35                  Ohio    11536504   39
# 36              Oklahoma     3751351   40
# 37                Oregon     3831074   41
# 38          Pennsylvania    12702379   42
# 39          Rhode Island     1052567   44
# 40        South Carolina     4625364   45
# 41          South Dakota      814180   46
# 42             Tennessee     6346105   47
# 43                 Texas    25145561   48
# 44                  Utah     2763885   49
# 45               Vermont      625741   50
# 46              Virginia     8001024   51
# 47            Washington     6724540   53
# 48         West Virginia     1852994   54
# 49             Wisconsin     5686986   55
# 50               Wyoming      563626   56
#
# [51 rows x 3 columns]

# %% [markdown]
# ### Pulling in Raw Data

# %%
#Let's get the data that we want
txt_dir = "/Users/Peter_Swigert/Documents/Berkeley/I_School/Open_Data/Backup/Data/"
e_location = (txt_dir+"ELEC.txt")

#TIFFANY- you can delete the two above rows, I think you use the e_location variable name in your notebook
f = open(e_location, 'r')
raw_data = []
temp_data = []

with open(e_location, 'r') as f:
    
    for row in f: #was doing it on 100,000
        line = json.loads(row)
        #Edit this to make it the actual rows that I want (annual, by sector etc)
        if 'Retail Sales of Electricity' in line['name']:
            if 'Annual' in line['name']:
                raw_data.append(line)

# %% [markdown]
# ### Getting this raw data into a dataframe of just the variables we ant

# %%
#That dataset has all the units and descriptions and stuff,let's just get the data we need
names = []
my_data = []
my_dict = {}

for x in raw_data:
    if 'Retail Sales of Electricity' in x['name'] and 'Annual' in x['name']: #Retail Sales of Electricity : Alaska : Residential/Commercial/Industrial/Transportation/Other : Annual
        my_dict[x['name']]=x['data']
#Let's make this dictionary a dataframe finally!
df = pd.DataFrame(my_dict)

# %% [markdown]
# ### This dataframe isn't structured exactly the way we want it to be. Time to clean it up

# %%
#Let's pull the column header into each row/record
d2 = df.unstack().reset_index()

#And rename the column header to get the data
d2 = d2.rename(columns={0: "Sales"})

#Then split the column header field into its components
parts = d2.pop("level_0").str.split(":")
#parts.to_csv("parts")

#And now create new columns based on those components
d2["State"] = [p[1].strip() for p in parts]
d2["Sector"] = [p[2].strip() for p in parts]

#Let's create a dictionary we can use to switch the level_1 fields to the actual years
temp_vals = range(0,13)
temp_years = sorted(range(2001,2014), reverse=True)

year_setter_dict = {}
for i in range(len(temp_vals)):
   year_setter_dict[temp_vals[i]] = temp_years[i]

#Turns the a column into years based on the dictionary matching
d2['level_1'] = d2['level_1'].map(lambda x: year_setter_dict[x])

#Now let's get rid of the year inside of the cell
import operator
d2['Year']=d2.Sales.apply(operator.itemgetter(-1), axis=1)

d2.rename(columns={'Year':'Data'}, inplace=True)

del d2['Sales']
d2.rename(columns={'Data': 'Sales'}, inplace=True)
d2.rename(columns={'level_1': 'Year'}, inplace=True)

#Messing around during group meeting
#Trying to figure out how to get it set up like Tiffany's DF
#Set the indices to State and Year
d3 = d2.set_index(['State', 'Year'])

#Then let's make columns that are for each of the sectors
d4 = d3.reset_index()
#d4.head()
Swigert_Sales = d4.pivot_table('Sales', ['State', 'Year'], 'Sector')
Swigert_Sales.head(100)
# Out:
# Sector             All Sectors    Commercial    Industrial        Other  \
# State      Year
# Alabama    2001   41903.059995  10050.574010  16580.656505   395.696505
#            2002   43905.809995  10485.299010  16929.863000   410.568995
#            2003   44386.682515  10904.817005  17686.143510          NaN
#            2004   46074.464500  11336.314500  18536.017000          NaN
#            2005   47483.170000  11613.638995  18959.979515          NaN
#            2006   48544.488490  11964.239495  19029.362500          NaN
#            2007   49391.165995  12431.584005  19039.464995          NaN
#            2008   48708.180755  12378.106935  18564.020745          NaN
#            2009   45079.585250  12061.000650  15595.858095          NaN
#            2010   49468.761845  12661.429850  17147.319020          NaN
#            2011   48547.710060  12294.251855  17921.315900          NaN
#            2012   47046.504920  12058.663600  17926.021080          NaN
#            2013   48049.635525  12412.051035  18149.457085          NaN
# Alaska     2001    3014.397500   1262.233010    580.800995   111.045015
#            2002    3018.680000   1232.513490    585.538995   118.134505
#            2003    3073.962495   1366.218005    595.207500          NaN
#            2004    3212.246005   1443.168000    609.895015          NaN
#            2005    3302.796500   1503.168995    631.725490          NaN
#            2006    3488.177500   1577.732005    693.129495          NaN
#            2007    3583.540510   1586.540995    779.285000          NaN
#            2008    3628.264690   1619.990910    767.443545          NaN
#            2009    3607.987405   1625.991240    741.927945          NaN
#            2010    3584.650120   1612.184960    755.686555          NaN
#            2011    3667.758250   1642.673800    769.870870          NaN
#            2012    3732.096105   1652.095060    806.751210          NaN
#            2013    3647.726120   1631.545565    771.952050          NaN
# Arizona    2001   33399.950505  11834.550495   5986.660490  1391.470995
#            2002   33557.403505  11999.869005   5799.935010  1458.942510
#            2003   34392.537495  13613.874510   5750.048500          NaN
#            2004   35959.240010  14003.801500   6271.797505          NaN
#            2005   37397.546490  14750.060505   6021.985985          NaN
#            2006   39643.448000  15460.388500   6478.448010          NaN
#            2007   41891.374500  16497.312490   6511.938495          NaN
#            2008   41609.694100  16427.680150   6857.680300          NaN
#            2009   40225.166655  16066.821955   5972.886410          NaN
#            2010   39945.892010  15842.300865   6100.441800          NaN
#            2011   41111.131650  16157.570205   6580.948145          NaN
#            2012   41212.172010  16260.903500   6630.605260          NaN
#            2013   41690.153500  16453.896825   6721.716175          NaN
# Arkansas   2001   22128.360500   4860.052515   8737.691500   395.953505
#            2002   22414.744985   4916.250000   8782.291005   389.387000
#            2003   22753.869520   5576.555005   8813.250500          NaN
#            2004   23073.795985   5668.156510   9021.005505          NaN
#            2005   24537.691005   6034.548495   9250.836005          NaN
#            2006   24947.671000   6193.176005   9466.599995          NaN
#            2007   25163.949995   6308.674990   9387.739500          NaN
#            2008   24820.740200   6296.863045   9021.035645          NaN
#            2009   23220.245245   6172.187355   7778.860700          NaN
#            2010   25850.559105   6539.416355   8843.959305          NaN
#            2011   25744.911005   6528.598550   8975.482260          NaN
#            2012   25214.574065   6517.807600   8909.510370          NaN
#            2013   25164.327315   6420.046660   8846.185635          NaN
# California 2001  137772.658485  54087.550505  34430.189000  6286.616995
#            2002  131946.687495  58148.463010  26599.753505  3718.068495
#            2003  135934.479000  61624.861000  27348.031010          NaN
#            2004  140312.117510  66399.431995  26668.816510          NaN
#            2005  141908.304005  65778.790000  27519.667010          NaN
#            2006  148335.181510  68445.568490  28067.954500          NaN
#            2007  149033.049985  69772.351995  27792.105000          NaN
#            2008  150811.663455  70351.769005  28078.367640          NaN
#                            ...           ...           ...          ...
#
# Sector            Residential  Transportation
# State      Year
# Alabama    2001  14876.133000             NaN
#            2002  16080.079000             NaN
#            2003  15795.722010             NaN
#            2004  16202.133000             NaN
#            2005  16909.551495             NaN
#            2006  17550.886500             NaN
#            2007  17920.117005             NaN
#            2008  17766.053055             NaN
#            2009  17422.726505             NaN
#            2010  19660.013000             NaN
#            2011  18332.142300             NaN
#            2012  17061.820250             NaN
#            2013  17488.127400             NaN
# Alaska     2001   1060.318500             NaN
#            2002   1082.493000             NaN
#            2003   1112.537000             NaN
#            2004   1159.183000             NaN
#            2005   1167.901995             NaN
#            2006   1217.316005             NaN
#            2007   1217.714495             NaN
#            2008   1240.830255             NaN
#            2009   1240.068195             NaN
#            2010   1216.778605             NaN
#            2011   1255.213600             NaN
#            2012   1273.249845             NaN
#            2013   1244.228510             NaN
# Arizona    2001  14187.268490             NaN
#            2002  14298.657005             NaN
#            2003  15028.614495             NaN
#            2004  15683.641000             NaN
#            2005  16625.500005             NaN
#            2006  17704.611490             NaN
#            2007  18882.123480             NaN
#            2008  18324.333650             NaN
#            2009  18185.458290             NaN
#            2010  18003.149360             NaN
#            2011  18372.613315             NaN
#            2012  18320.663250             NaN
#            2013  18514.540500             NaN
# Arkansas   2001   8134.662985             NaN
#            2002   8326.817005             NaN
#            2003   8364.063995        0.000000
#            2004   8384.633990        0.000000
#            2005   9252.306505        0.000000
#            2006   9287.895000        0.000000
#            2007   9467.535505        0.000000
#            2008   9502.613465        0.228060
#            2009   9268.981550        0.215655
#            2010  10466.949650        0.233810
#            2011  10240.592470        0.237750
#            2012   9786.998625        0.257510
#            2013   9897.896255             NaN
# California 2001  42968.302005             NaN
#            2002  43480.402505             NaN
#            2003  46533.728495      427.858505
#            2004  46764.859505      479.009510
#            2005  48158.984505      450.862500
#            2006  51355.644015      466.014495
#            2007  51009.147010      459.446005
#            2008  51912.774295      468.752495
#                           ...             ...
#
# [100 rows x 6 columns]
